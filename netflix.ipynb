# %% [markdown]
# # NETFLIX DATA ANALYSIS

# %% [markdown]
# ---

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd #data handling
import matplotlib.pyplot as plt #visualization
import seaborn as sns # visualization

# %% [markdown]
# ---

# %% [markdown]
# ## LADING DATA

# %%
df = pd.read_csv("netflix.csv")
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Inspect data

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
df.sample()
# Out:
#      show_id   type           title           director  \
# 6403   s6404  Movie  Calendar Girls  Madhur Bhandarkar
#
#                                                    cast country  \
# 6403  Akanksha Puri, Avani Modi, Kyra Dutt, Ruhi Sin...   India
#
#             date_added  release_year rating duration  \
# 6403  October 15, 2017          2015  TV-14  126 min
#
#                          listed_in  \
# 6403  Dramas, International Movies
#
#                                             description
# 6403  Five calendar models try to navigate the twist...

# %%
df.dtypes #check the coloumns data type
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df.columns #display coloumns names
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.shape #display no. of rows and coloumns
# Out:
# (8807, 12)

# %% [markdown]
# ---

# %% [markdown]
# ## INFORMATION OF DATA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# - total entries = 8807 entries,0 to 8806
# - Data coloums = 12
# - memory usage = 825.8kb
# - missing values (director) = 2634
# - missing values (cast) = 825
# - missing values (country) = 831
# - missing values (date_added) = 10
# - missing values (ratings) = 4
# - missing values (duration) = 3
# - data type mistakes (duration) = duration is  integer,not object
# - data type mistake (rating) = The heding of rating is not suitable fore here,the heading is change into category

# %% [markdown]
# ---

# %% [markdown]
# ## Selecting coloumn

# %% [markdown]
# ### Single coloumn

# %%
df['title'] #single coloumn selecting prompt
# Out:
# 0        Dick Johnson Is Dead
# 1               Blood & Water
# 2                   Ganglands
# 3       Jailbirds New Orleans
# 4                Kota Factory
#                 ...
# 8802                   Zodiac
# 8803              Zombie Dumb
# 8804               Zombieland
# 8805                     Zoom
# 8806                   Zubaan
# Name: title, Length: 8807, dtype: object

# %%
df[['type','cast']]  #selecting mulpiple coloumns
# Out:
#          type                                               cast
# 0       Movie                                                NaN
# 1     TV Show  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     TV Show  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3     TV Show                                                NaN
# 4     TV Show  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# ...       ...                                                ...
# 8802    Movie  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8803  TV Show                                                NaN
# 8804    Movie  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805    Movie  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806    Movie  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
# [8807 rows x 2 columns]

# %%
newdf=df[['type','cast']]
print(newdf)
# Out:
#          type                                               cast
# 0       Movie                                                NaN
# 1     TV Show  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     TV Show  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3     TV Show                                                NaN
# 4     TV Show  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# ...       ...                                                ...
# 8802    Movie  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8803  TV Show                                                NaN
# 8804    Movie  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805    Movie  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806    Movie  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
# [8807 rows x 2 columns]

# %%
newdf[['type','cast']].head()
# Out:
#       type                                               cast
# 0    Movie                                                NaN
# 1  TV Show  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2  TV Show  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3  TV Show                                                NaN
# 4  TV Show  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...

# %% [markdown]
# ---

# %% [markdown]
# ## Filter the data

# %%
df[df['release_year']<2010]
# Out:
#      show_id   type                 title          director  \
# 7         s8  Movie               Sankofa      Haile Gerima
# 22       s23  Movie       Avvai Shanmughi    K.S. Ravikumar
# 24       s25  Movie                 Jeans        S. Shankar
# 26       s27  Movie        Minsara Kanavu       Rajiv Menon
# 41       s42  Movie                  Jaws  Steven Spielberg
# ...      ...    ...                   ...               ...
# 8793   s8794  Movie  Yours, Mine and Ours      Raja Gosnell
# 8799   s8800  Movie                 Zenda    Avadhoot Gupte
# 8802   s8803  Movie                Zodiac     David Fincher
# 8804   s8805  Movie            Zombieland   Ruben Fleischer
# 8805   s8806  Movie                  Zoom      Peter Hewitt
#
#                                                    cast  \
# 7     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 22    Kamal Hassan, Meena, Gemini Ganesan, Heera Raj...
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
# ...

# %% [markdown]
# ---

# %%
df[df['type']=='TV Show']
# Out:
#      show_id     type                  title         director  \
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8795   s8796  TV Show        Yu-Gi-Oh! Arc-V              NaN
# 8796   s8797  TV Show             Yunus Emre              NaN
# 8797   s8798  TV Show              Zak Storm              NaN
# 8800   s8801  TV Show     Zindagi Gulzar Hai              NaN
# 8803   s8804  TV Show            Zombie Dumb              NaN
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %% [markdown]
# ---

# %%
df[df['director']=='Mike Flanagan']
# Out:
#      show_id     type          title       director  \
# 5         s6  TV Show  Midnight Mass  Mike Flanagan
# 5091   s5092    Movie  Before I Wake  Mike Flanagan
# 5252   s5253    Movie  Gerald's Game  Mike Flanagan
# 5852   s5853    Movie           Hush  Mike Flanagan
#
#                                                    cast        country  \
# 5     Kate Siegel, Zach Gilford, Hamish Linklater, H...            NaN
# 5091  Kate Bosworth, Thomas Jane, Jacob Tremblay, An...  United States
# 5252  Carla Gugino, Bruce Greenwood, Henry Thomas, C...  United States
# 5852  John Gallagher Jr., Kate Siegel, Michael Trucc...  United States
#
#               date_added  release_year rating  duration  \
# 5     September 24, 2021          2021  TV-MA  1 Season
# 5091     January 5, 2018          2016  PG-13    97 min
# 5252  September 29, 2017          2017  TV-MA   103 min
# 5852       April 8, 2016          2016      R    82 min
#
#                                listed_in  \
# ...

# %% [markdown]
# ---

# %%
df[df['listed_in']=="Kids' TV"]
# Out:
#      show_id     type                    title director  \
# 34       s35  TV Show  Tayo and Little Wizards      NaN
# 39       s40  TV Show             Chhota Bheem      NaN
# 65       s66  TV Show             Numberblocks      NaN
# 89       s90  TV Show              Mighty Raju      NaN
# 100     s101  TV Show  Tobot Galaxy Detectives      NaN
# ...      ...      ...                      ...      ...
# 8669   s8670  TV Show            V.R. Troopers      NaN
# 8679   s8680  TV Show       ViR: The Robot Boy      NaN
# 8783   s8784  TV Show                     Yoko      NaN
# 8785   s8786  TV Show                      YOM      NaN
# 8797   s8798  TV Show                Zak Storm      NaN
#
#                                                    cast  \
# 34    Dami Lee, Jason Lee, Bommie Catherine Han, Jen...
# 39    Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...
# 65    Beth Chalmers, David Holt, Marcel McCalla, Ter...
# 89    Julie Tejwani, Sabina Malik, Jigna Bhardwaj, R...
# ...

# %% [markdown]
# ---

# %%
df[df['country']=='India']
# Out:
#      show_id     type                          title                 director  \
# 4         s5  TV Show                   Kota Factory                      NaN
# 24       s25    Movie                          Jeans               S. Shankar
# 39       s40  TV Show                   Chhota Bheem                      NaN
# 50       s51  TV Show                  Dharmakshetra                      NaN
# 66       s67  TV Show  Raja Rasoi Aur Anya Kahaniyan                      NaN
# ...      ...      ...                            ...                      ...
# 8773   s8774    Movie            Yanda Kartavya Aahe             Kedar Shinde
# 8775   s8776  TV Show                Yeh Meri Family                      NaN
# 8798   s8799    Movie                       Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie                          Zenda           Avadhoot Gupte
# 8806   s8807    Movie                         Zubaan              Mozez Singh
#
# ...

# %% [markdown]
# ---

# %%
df[(df['country']=='India')&(df['release_year']<2020)]
# Out:
#      show_id     type                           title  \
# 24       s25    Movie                           Jeans
# 50       s51  TV Show                   Dharmakshetra
# 66       s67  TV Show   Raja Rasoi Aur Anya Kahaniyan
# 69       s70  TV Show  Stories by Rabindranath Tagore
# 105     s106    Movie                Angamaly Diaries
# ...      ...      ...                             ...
# 8773   s8774    Movie             Yanda Kartavya Aahe
# 8775   s8776  TV Show                 Yeh Meri Family
# 8798   s8799    Movie                        Zed Plus
# 8799   s8800    Movie                           Zenda
# 8806   s8807    Movie                          Zubaan
#
#                      director  \
# 24                 S. Shankar
# 50                        NaN
# 66                        NaN
# 69                        NaN
# 105      Lijo Jose Pellissery
# ...                       ...
# 8773             Kedar Shinde
# 8775                      NaN
# 8798  Chandra Prakash Dwivedi
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Selecting rows

# %%
df.iloc[9] #single row
df.iloc[4:11] #portion
# Out:
#    show_id     type                                title  \
# 4       s5  TV Show                         Kota Factory
# 5       s6  TV Show                        Midnight Mass
# 6       s7    Movie     My Little Pony: A New Generation
# 7       s8    Movie                              Sankofa
# 8       s9  TV Show        The Great British Baking Show
# 9      s10    Movie                         The Starling
# 10     s11  TV Show  Vendetta: Truth, Lies and The Mafia
#
#                          director  \
# 4                             NaN
# 5                   Mike Flanagan
# 6   Robert Cullen, José Luis Ucha
# 7                    Haile Gerima
# 8                 Andy Devonshire
# 9                  Theodore Melfi
# 10                            NaN
#
#                                                  cast  \
# 4   Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 5   Kate Siegel, Zach Gilford, Hamish Linklater, H...
# 6   Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### loc method

# %%
df.loc[5050,'director']
# Out:
# 'Ildiko Enyedi'

# %% [markdown]
# ---

# %% [markdown]
# ### Rename column

# %%
df.rename(columns={"rating":"category"},inplace=True)
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year category   duration  \
# 0  September 25, 2021          2020    PG-13     90 min
# 1  September 24, 2021          2021    TV-MA  2 Seasons
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Counts

# %%
df['country'].value_counts()
# Out:
# country
# United States                             2818
# India                                      972
# United Kingdom                             419
# Japan                                      245
# South Korea                                199
#                                           ...
# Romania, Bulgaria, Hungary                   1
# Uruguay, Guatemala                           1
# France, Senegal, Belgium                     1
# Mexico, United States, Spain, Colombia       1
# United Arab Emirates, Jordan                 1
# Name: count, Length: 748, dtype: int64

# %%
df['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ## Data Cleaning

# %%
#remove text units and convert to numbers
#df['duration'] = pd.to_numeric(
 #   df['engine']
  #  .astype(str)
   # .str.replace(r'[^0-9.-]','',regex=true)
    #.replace('',none),
    #errors='coerce'
#)
################  The code is not work in the program.the unit is different

# %% [markdown]
# ---

# %%
# parse date_added as datetime
df["date_added"]=pd.to_datetime(df['date_added'],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   datetime64[ns]
#  7   release_year  8807 non-null   int64
#  8   category      8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 825.8+ KB

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ----

# %%
category={
    #kids
    'TV-Y':'Kids',
    'TV-Y7':'Kids',
    'TV-Y7-FV':'Kids',
    'G':'Kids',
    
    #General
    'TV-G':'General',
    'PG':'General',
    
    #Teen
    'TV-PG':'Teen',
    'TV-14':'Teen',
    'PG-13':'Teen',
    
    #Adult
    'TV-MA':'Adult',
    'R':'Adult',
    'NC-17':'Adult',
    
    #Unknown
    'NR':'Unknown',
    'UR':'Unknown',
}
df['category']=df['category'].map(category)

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Handling missing values

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# category           7
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# ### How to fill missing values
# - Numerical-fill with median
# - Categorical-fill with mode

# %%
df['director'].fillna('Unknown',inplace=True)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_7356\4009837435.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['director'].fillna('Unknown',inplace=True)

# %%
df['country'].fillna('Unknown',inplace=True)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_7356\141793252.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['country'].fillna('Unknown',inplace=True)

# %%
df['cast'].fillna('Unknown',inplace=True)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_7356\2343259098.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['cast'].fillna('Unknown',inplace=True)

# %%
df.isnull().sum()
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast             0
# country          0
# date_added      10
# release_year     0
# category         7
# duration         3
# listed_in        0
# description      0
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# - dropping rows

# %%
df.dropna(subset=['date_added','category','duration'],inplace=True)
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb          Unknown
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               Unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# category        0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df.shape
# Out:
# (8790, 12)

# %% [markdown]
# ---

# %% [markdown]
# ## Handling duplicated

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ----

# %% [markdown]
# - data cleaning compleated

# %% [markdown]
# ---

# %% [markdown]
# ### Ensuring data cleaned

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          Unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          Unknown
# 4      s5  TV Show           Kota Factory          Unknown
#
#                                                 cast        country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                            Unknown        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year category   duration  \
# 0 2021-09-25          2020     Teen     90 min
# 1 2021-09-24          2021    Adult  2 Seasons
# 2 2021-09-24          2021    Adult   1 Season
# ...

# %%
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb          Unknown
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                            Unknown        Unknown
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#      date_added  release_year category   duration  \
# 8802 2019-11-20          2007    Adult    158 min
# 8803 2019-07-01          2018     Kids  2 Seasons
# 8804 2019-11-01          2009    Adult     88 min
# ...

# %%
df.shape
# Out:
# (8790, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8790 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   cast          8790 non-null   object
#  5   country       8790 non-null   object
#  6   date_added    8790 non-null   datetime64[ns]
#  7   release_year  8790 non-null   int64
#  8   category      8790 non-null   object
#  9   duration      8790 non-null   object
#  10  listed_in     8790 non-null   object
#  11  description   8790 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 892.7+ KB

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'category', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# ---

# %% [markdown]
# ## TV Shows

# %%
TV=df[df['type']=='TV Show']
TV
# Out:
#      show_id     type                  title         director  \
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8795   s8796  TV Show        Yu-Gi-Oh! Arc-V          Unknown
# 8796   s8797  TV Show             Yunus Emre          Unknown
# 8797   s8798  TV Show              Zak Storm          Unknown
# 8800   s8801  TV Show     Zindagi Gulzar Hai          Unknown
# 8803   s8804  TV Show            Zombie Dumb          Unknown
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Movies

# %%
movie=df[df['type']=='Movie']
movie
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## save the Netflix new csv file

# %%
df.to_csv('netflix_cleaned.csv',index=False)

# %% [markdown]
# ---

# %%
df_new = pd.read_csv('netflix_cleaned.csv')

# %%
df_new
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# ...      ...      ...                    ...              ...
# 8785   s8803    Movie                 Zodiac    David Fincher
# 8786   s8804  TV Show            Zombie Dumb          Unknown
# 8787   s8805    Movie             Zombieland  Ruben Fleischer
# 8788   s8806    Movie                   Zoom     Peter Hewitt
# 8789   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               Unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Summery statistics

# %%
df_new.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'category', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# ---

# %% [markdown]
# ### Average(mean)

# %%
print('release_year :',df_new['release_year'].mean())
# Out:
# release_year : 2014.183162684869

# %% [markdown]
# ### Median

# %%
print('release_year :',df_new['release_year'].median())
# Out:
# release_year : 2017.0

# %% [markdown]
# ### Mode

# %%
print('release_year :',df_new['release_year'].mode())
# Out:
# release_year : 0    2018
# Name: release_year, dtype: int64

# %%
df_new.select_dtypes(include=object).mode()
# Out:
#      show_id   type                          title director     cast  \
# 0         s1  Movie                         #Alive  Unknown  Unknown
# 1        s10    NaN  #AnneFrank - Parallel Stories      NaN      NaN
# 2       s100    NaN              #FriendButMarried      NaN      NaN
# 3      s1000    NaN            #FriendButMarried 2      NaN      NaN
# 4      s1001    NaN                          #Roxy      NaN      NaN
# ...      ...    ...                            ...      ...      ...
# 8785    s995    NaN                       忍者ハットリくん      NaN      NaN
# 8786    s996    NaN                           海的儿子      NaN      NaN
# 8787    s997    NaN                           마녀사냥      NaN      NaN
# 8788    s998    NaN                        반드시 잡는다      NaN      NaN
# 8789    s999    NaN            최강전사 미니특공대 : 영웅의 탄생      NaN      NaN
#
#             country  date_added category  duration  \
# 0     United States  2020-01-01    Adult  1 Season
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### STD

# %%
df_new.select_dtypes(include='number').std()
# Out:
# release_year    8.825466
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ### Describe

# %%
df_new.describe()
# Out:
#        release_year
# count   8790.000000
# mean    2014.183163
# std        8.825466
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %% [markdown]
# - min year:1925
# - max year:2025
# - 75% upper data year started to 2019
# - 50% upper data year started to 2017
# - 25% upper data year started to 2013
# - mean:2014.18
# - std:8.825
# - median:2017

# %%
df_new.describe(include=object)
# Out:
#        show_id   type                 title director     cast        country  \
# count     8790   8790                  8790     8790     8790           8790
# unique    8790      2                  8790     4527     7679            749
# top         s1  Movie  Dick Johnson Is Dead  Unknown  Unknown  United States
# freq         1   6126                     1     2621      825           2809
#
#         date_added category  duration                     listed_in  \
# count         8790     8790      8790                          8790
# unique        1713        5       220                           513
# top     2020-01-01    Adult  1 Season  Dramas, International Movies
# freq           110     4007      1791                           362
#
#                                               description
# count                                                8790
# unique                                               8758
# top     Paranormal activity at a lush, abandoned prope...
# ...

# %% [markdown]
# - Total no of data 8790
# - Two type data show in type,movies and tv show.
# - The most common of them is movie,(6126 movies)
# - All data title is different
# - Total director's 4527,most director's data is unknown ,(2621 unknown datas)
# - Total cast is 7679,most cast data is unknown ,(825 unknown datas)
# - 749 countrys uploaded datas
# - United states is most type data uploade.(2809 datas)
# - The most data come in 2020-01-01,(110 datas)
# - The 5 category data is uploaded,the most data is adult,(4007 datas)
# - The 513 listed in data,the most data is Dramas, International Movies,(362 datas)

# %% [markdown]
# ---

# %% [markdown]
# # Data Visualisation

# %% [markdown]
# ## Histogram

# %% [markdown]
# - Distribution of numerical data

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(50,20))
sns.histplot(data=df_new,x="date_added",bins=20,color='red')
sns.histplot(data=df_new,x="date_added")
plt.title('DISTRIBUTION OF DATE ADDED')
plt.ylabel('y')
plt.xlabel('date added year')
plt.show()

# %%
df.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# category                object
# duration                object
# listed_in               object
# description             object
# dtype: object
